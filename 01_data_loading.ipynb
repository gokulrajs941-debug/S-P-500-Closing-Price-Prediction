# %%
import yfinance as yf
import pandas as pd

TICKER = "^GSPC"   # S&P 500 index
PERIOD = "5y"       # 5 years of history
INTERVAL = "1d"      # daily candles

# %%
data = yf.download(TICKER, period=PERIOD, interval=INTERVAL)
data = data.reset_index()
data.columns = data.columns.get_level_values(0)

print(data.shape)
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1254, 6)
# Price       Date        Close         High          Low         Open  \
# 0     2021-09-02  4536.950195  4545.850098  4524.660156  4534.479980
# 1     2021-09-03  4535.430176  4541.450195  4521.299805  4532.419922
# 2     2021-09-07  4520.029785  4535.379883  4513.000000  4535.379883
# 3     2021-09-08  4514.069824  4521.790039  4493.950195  4518.089844
# 4     2021-09-09  4493.279785  4529.899902  4492.069824  4513.020020
#
# Price      Volume
# 0      3735990000
# 1      3217530000
# 2      3822960000
# 3      3750880000
# 4      3735390000

# %%
data.to_csv("sp500_raw.csv", index=False)
